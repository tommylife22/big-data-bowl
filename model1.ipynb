# %% [markdown]
# ### Building the Targets: Future Sequence per Player

# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

inputs = pd.read_csv(r'data/train/input_2023_w01.csv')
outputs = pd.read_csv(r'data/train/output_2023_w01.csv')
